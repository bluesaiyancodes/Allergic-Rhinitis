# %%
import cv2
import pandas as pd
import numpy as np

# %%
dataF = pd.read_csv('ARStats.csv')

# %%
dataF.tail(21)
# Out:
#     imageid imageType      model   loss   classType colorMode  clean  crop  \
# 253     254        NR   xception  focal  multiclass       RGB   True  True
# 254     255         R  inception  focal  multiclass       RGB   True  True
# 255     256         R  inception  focal  multiclass       RGB   True  True
# 256     257         R  inception  focal  multiclass       RGB   True  True
# 257     258         R  inception  focal  multiclass       RGB   True  True
# 258     259         R  inception  focal  multiclass       RGB   True  True
# 259     260         R  inception  focal  multiclass       RGB   True  True
# 260     261         R  inception  focal  multiclass       RGB   True  True
# 261     262         R  inception  focal  multiclass       RGB   True  True
# 262     263         R  inception  focal  multiclass       RGB   True  True
# 263     264         R  inception  focal  multiclass       RGB   True  True
# 264     265         R   xception  focal  multiclass       RGB   True  True
# 265     266         R   xception  focal  multiclass       RGB   True  True
# 266     267         R   xception  focal  multiclass       RGB   True  True
# 267     268         R   xception  focal  multiclass       RGB   True  True
# 268     269         R   xception  focal  multiclass       RGB   True  True
# 269     270         R   xception  focal  multiclass       RGB   True  True
# 270     271         R   xception  focal  multiclass       RGB   True  True
# 271     272         R   xception  focal  multiclass       RGB   True  True
# 272     273         R   xception  focal  multiclass       RGB   True  True
# 273     274         R   xception  focal  multiclass       RGB   True  True
#
#      resize  colorCorrect  ...  activation wloss     lr  learningDecay  \
# 253    True         False  ...       siren  True  0.001          False
# 254    True         False  ...       siren  True  0.001          False
# 255    True         False  ...       siren  True  0.001          False
# 256    True         False  ...       siren  True  0.001          False
# 257    True         False  ...       siren  True  0.001          False
# 258    True         False  ...       siren  True  0.001          False
# 259    True         False  ...       siren  True  0.001          False
# 260    True         False  ...       siren  True  0.001          False
# 261    True         False  ...       siren  True  0.001          False
# 262    True         False  ...       siren  True  0.001          False
# 263    True         False  ...       siren  True  0.001          False
# 264    True         False  ...       siren  True  0.001          False
# 265    True         False  ...       siren  True  0.001          False
# 266    True         False  ...       siren  True  0.001          False
# 267    True         False  ...       siren  True  0.001          False
# 268    True         False  ...       siren  True  0.001          False
# 269    True         False  ...       siren  True  0.001          False
# 270    True         False  ...       siren  True  0.001          False
# 271    True         False  ...       siren  True  0.001          False
# 272    True         False  ...       siren  True  0.001          False
# 273    True         False  ...       siren  True  0.001          False
#
#      earlyStop  epochsMax  epochs  voting   trainTime   accuracy
# 253       True        200     196      10   93.099728       83.0
# 254       True        200     161      10   77.242793       77.0
# 255       True        200     200      10   93.694197       61.0
# 256       True        200     188      10   88.559638       72.0
# 257       True        200     200      10   94.276368       66.0
# 258       True        200     180      10   86.088634       77.0
# 259       True        200     156      10   73.894257       50.0
# 260       True        200     200      10   94.162140       61.0
# 261       True        200     191      10   90.496320       83.0
# 262       True        200     120      10   57.263969       61.0
# 263       True        200     188      10   88.569650       77.0
# 264       True        200     105      10   50.334046       77.0
# 265       True        200     142      10   68.037925       72.0
# 266       True        200      99      10   47.425224       66.0
# 267       True        200     113      10   54.265565       66.0
# 268       True        200     189      10   89.480313       66.0
# 269       True        200     122      10   58.825760       72.0
# 270       True        200     122      10   58.428563       77.0
# 271       True        200     128      10   61.412892       77.0
# 272       True        200     184      10   87.828767       77.0
# 273       True        200     102      10   49.026180       72.0
#
# [21 rows x 21 columns]

# %%
data = dataF.to_numpy()

# %%
#data[114:134]

# %%
data20 = data[254:274]

# %%
len(data20)
# Out:
# 20

# %%
accInc = []
accXc = []
timeIn = []
timeX = []
for i in range(len(data20)):
    if data20[i][2] == 'inception':
        accInc.append(data20[i][-1])
        timeIn.append(data20[i][-2])
    elif data20[i][2] == "xception":
        accXc.append(data20[i][-1])
        timeX.append(data20[i][-2])
    else:
        print(data[i][2])
print("NR Data")
print("Inception - %.2f%% (+/- %.2f%%) time - %d" % (np.mean(accInc), np.std(accInc), np.sum(timeIn)/60))  
print("Xception  - %.2f%% (+/- %.2f%%)" % (np.mean(accXc), np.std(accXc)))
# Out:
# NR Data
# Inception - 75.00% (+/- 8.09%) time - 12
# Xception  - 83.30% (+/- 3.82%)

# %%
timeIn
# Out:
# [84.00198153999918,
#  63.64380408500074,
#  71.43769831400095,
#  70.76591232200008,
#  94.61041517299964,
#  94.9362284079998,
#  48.29455093399884,
#  75.92172913600007,
#  92.89785221900092,
#  72.37121481099894]

# %% [markdown]
# [83.0, 83.0, 88.0, 88.0, 77.0, 77.0, 83.0, 83.0, 88.0, 83.0]

# %%
rdata20 = data[114:134]
len(rdata20)
# Out:
# 20

# %%
accInc = []
accXc = []
timeIn = []
timeX = []
for i in range(len(rdata20)):
    if rdata20[i][2] == 'inception':
        accInc.append(rdata20[i][-1])
        timeIn.append(data[i][-2])
    elif rdata20[i][2] == "xception":
        accXc.append(rdata20[i][-1])
        timeX.append(data[i][-2])
print("R Data")
print("Inception - %.2f%% (+/- %.2f%%) time - %d" % (np.mean(accInc), np.std(accInc), np.sum(timeIn)/60))  
print("Xception  - %.2f%% (+/- %.2f%%) time - %d" % (np.mean(accXc), np.std(accXc), np.sum(timeIn)/60))
# Out:
# R Data
# Inception - 75.10% (+/- 7.06%) time - 27
# Xception  - 82.90% (+/- 2.47%) time - 27

# %% [markdown]
# # For 5 fold CV

# %%
cvData = []
cvIn =[]
cvX = []
timeIn = []
timeX = []
for i in range(len(data)):
    if data[i][1] == "CV-R":
        cvData.append(data)
        if data[i][2] == 'inception':
            cvIn.append(data[i][-1])
            timeIn.append(data[i][-2])
        elif data[i][2] == 'xception':
            cvX.append(data[i][-1])
            timeX.append(data[i][-2])

# %%
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvIn), np.std(cvIn)))
# Out:
# 68.40% (+/- 9.22%)

# %%
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvX), np.std(cvX)))
# Out:
# 63.80% (+/- 8.93%)

# %%
np.sum(timeIn)/60
# Out:
# 5.641051001616673

# %%
np.sum(timeX)/60
# Out:
# 5.30753816983334

# %%
(99.78571799909696 * 90) /3600
# Out:
# 2.494642949977424

# %%
(100.15781449293718* 90) /3600
# Out:
# 2.5039453623234293

# %%
a = {}
a["ball"] = 7
a.get("ball")
# Out:
# 7
