# %%
import cv2
import pandas as pd
import numpy as np

# %%
dataF = pd.read_csv('ARStats.csv')

# %%
dataF.tail(21)
# Out:
#      imageid imageType      model   loss   classType colorMode  clean  crop  \
# 133      134         R   xception  focal  multiclass       RGB   True  True
# 134      135        NR  inception  focal  multiclass       RGB   True  True
# 135      136        NR  inception  focal  multiclass       RGB   True  True
# 136      137        NR  inception  focal  multiclass       RGB   True  True
# 137      138        NR  inception  focal  multiclass       RGB   True  True
# 138      139        NR  inception  focal  multiclass       RGB   True  True
# 139      140        NR  inception  focal  multiclass       RGB   True  True
# 140      141        NR  inception  focal  multiclass       RGB   True  True
# 141      142        NR  inception  focal  multiclass       RGB   True  True
# 142      143        NR  inception  focal  multiclass       RGB   True  True
# 143      144        NR  inception  focal  multiclass       RGB   True  True
# 144      145        NR   xception  focal  multiclass       RGB   True  True
# 145      146        NR   xception  focal  multiclass       RGB   True  True
# 146      147        NR   xception  focal  multiclass       RGB   True  True
# 147      148        NR   xception  focal  multiclass       RGB   True  True
# 148      149        NR   xception  focal  multiclass       RGB   True  True
# 149      150        NR   xception  focal  multiclass       RGB   True  True
# 150      151        NR   xception  focal  multiclass       RGB   True  True
# 151      152        NR   xception  focal  multiclass       RGB   True  True
# 152      153        NR   xception  focal  multiclass       RGB   True  True
# 153      154        NR   xception  focal  multiclass       RGB   True  True
#
#      resize  colorCorrect  ...  activation wloss     lr  learningDecay  \
# 133    True         False  ...       siren  True  0.001          False
# 134    True         False  ...       siren  True  0.001          False
# 135    True         False  ...       siren  True  0.001          False
# 136    True         False  ...       siren  True  0.001          False
# 137    True         False  ...       siren  True  0.001          False
# 138    True         False  ...       siren  True  0.001          False
# 139    True         False  ...       siren  True  0.001          False
# 140    True         False  ...       siren  True  0.001          False
# 141    True         False  ...       siren  True  0.001          False
# 142    True         False  ...       siren  True  0.001          False
# 143    True         False  ...       siren  True  0.001          False
# 144    True         False  ...       siren  True  0.001          False
# 145    True         False  ...       siren  True  0.001          False
# 146    True         False  ...       siren  True  0.001          False
# 147    True         False  ...       siren  True  0.001          False
# 148    True         False  ...       siren  True  0.001          False
# 149    True         False  ...       siren  True  0.001          False
# 150    True         False  ...       siren  True  0.001          False
# 151    True         False  ...       siren  True  0.001          False
# 152    True         False  ...       siren  True  0.001          False
# 153    True         False  ...       siren  True  0.001          False
#
#      earlyStop  epochsMax  epochs  voting   trainTime   accuracy
# 133       True        200     106       0   50.504919       83.0
# 134       True        200     174       0   84.001982       88.0
# 135       True        200     133       0   63.643804       77.0
# 136       True        200     150       0   71.437698       77.0
# 137       True        200     148       0   70.765912       77.0
# 138       True        200     200       0   94.610415       61.0
# 139       True        200     200       0   94.936228       61.0
# 140       True        200     100       0   48.294551       72.0
# 141       True        200     159       0   75.921729       77.0
# 142       True        200     197       0   92.897852       77.0
# 143       True        200     151       0   72.371215       83.0
# 144       True        200     196       0   93.586916       83.0
# 145       True        200     116       0   56.563245       83.0
# 146       True        200     123       0   59.347780       88.0
# 147       True        200     107       0   52.036392       88.0
# 148       True        200     102       0   49.622207       77.0
# 149       True        200     136       0   65.326314       77.0
# 150       True        200     114       0   55.377421       83.0
# 151       True        200     107       0   51.941994       83.0
# 152       True        200     128       0   61.419348       88.0
# 153       True        200     157       0   75.613573       83.0
#
# [21 rows x 21 columns]

# %%
data = dataF.to_numpy()

# %%
#data[114:134]

# %%
data20 = data[134:153]

# %%
len(data[:])
# Out:
# 154

# %%
accInc = []
accXc = []
timeIn = []
timeX = []
for i in range(len(data20)):
    if data20[i][2] == 'inception':
        accInc.append(data20[i][-1])
        timeIn.append(data[i][-2])
    elif data[i][2] == "xception":
        accXc.append(data20[i][-1])
        timeX.append(data[i][-2])
print("NR Data")
print("Inception - %.2f%% (+/- %.2f%%) time - %d" % (np.mean(accInc), np.std(accInc), np.sum(timeIn)/60))  
print("Xception  - %.2f%% (+/- %.2f%%) time - %d" % (np.mean(accXc), np.std(accXc), np.sum(timeIn)/60))
# Out:
# NR Data
# Inception - 75.00% (+/- 8.09%) time - 27
# Xception  - 82.50% (+/- 5.50%) time - 27

# %%
rdata20 = data[114:134]
len(rdata20)
# Out:
# 20

# %%
accInc = []
accXc = []
timeIn = []
timeX = []
for i in range(len(rdata20)):
    if rdata20[i][2] == 'inception':
        accInc.append(rdata20[i][-1])
        timeIn.append(data[i][-2])
    elif rdata20[i][2] == "xception":
        accXc.append(rdata20[i][-1])
        timeX.append(data[i][-2])
print("R Data")
print("Inception - %.2f%% (+/- %.2f%%) time - %d" % (np.mean(accInc), np.std(accInc), np.sum(timeIn)/60))  
print("Xception  - %.2f%% (+/- %.2f%%) time - %d" % (np.mean(accXc), np.std(accXc), np.sum(timeIn)/60))
# Out:
# R Data
# Inception - 75.10% (+/- 7.06%) time - 27
# Xception  - 82.90% (+/- 2.47%) time - 27

# %% [markdown]
# # For 5 fold CV

# %%
cvData = []
cvIn =[]
cvX = []
timeIn = []
timeX = []
for i in range(len(data)):
    if data[i][1] == "CV-R":
        cvData.append(data)
        if data[i][2] == 'inception':
            cvIn.append(data[i][-1])
            timeIn.append(data[i][-2])
        elif data[i][2] == 'xception':
            cvX.append(data[i][-1])
            timeX.append(data[i][-2])

# %%
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvIn), np.std(cvIn)))
# Out:
# 68.40% (+/- 9.22%)

# %%
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvX), np.std(cvX)))
# Out:
# 63.80% (+/- 8.93%)

# %%
np.sum(timeIn)/60
# Out:
# 5.641051001616673

# %%
np.sum(timeX)/60
# Out:
# 5.30753816983334

# %%
(99.78571799909696 * 90) /3600
# Out:
# 2.494642949977424

# %%
(100.15781449293718* 90) /3600
# Out:
# 2.5039453623234293

# %%
|
