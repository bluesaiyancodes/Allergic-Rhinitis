# %%
from turtle import colormode
from imutils import paths
import imutils
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import timeit
from datetime import datetime
from random import shuffle

from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.utils import class_weight

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, VGG19, InceptionResNetV2, DenseNet121, ResNet50V2, ResNet101V2, Xception, InceptionV3
from tensorflow.keras.layers import AveragePooling2D, Dropout, Flatten, Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import losses

import tensorflow_addons as tfa
# Out:
# 2022-09-27 20:59:58.623444: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
path = r'/home/bishal/Research/Allergic-Rhinitis/Dataset/rotate'
dirList = {}
imagePaths = list(paths.list_images(path))
imagePaths
# Out:
# ['/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/1/28_1_00003_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/1/33_1_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/1/33_1_00005_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/0/n32_3_00004_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/0/n29_1_00004_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/0/n32_4_00004_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/0/n32_3_00003_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/0/n29_3_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/0/n32_2_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/0/n29_3_00005_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/0/n32_4_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/0/n32_1_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/2/20_1_00006_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/2/20_2_00008_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/2/20_2_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/2/20_1_00009_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/2/20_3_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset3/2/21_1_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset4/1/30_1_00013_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset4/1/34_1_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset4/1/30_1_00011_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset4/0/n34_2_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset4/0/n35_2_00007_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset4/0/n35_1_00011_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset4/0/n35_2_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset4/0/n35_2_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset4/0/n35_1_00012_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset4/0/n35_1_00010_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset4/0/n35_1_00009_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset4/2/35_1_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset4/2/27_1_00005_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset4/2/35_3_00004_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset4/2/35_3_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset4/2/35_2_00003_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset4/2/22_1_00005_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/1/13_2_00004_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/1/13_1_00005_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/1/13_2_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/1/13_1_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/0/n18_2_00003_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/0/n17_5_00003_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/0/n19_3_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/0/n17_7_00013_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/0/n19_4_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/0/n19_4_00003_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/0/n18_2_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/0/n17_4_00006_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/0/n19_2_00003_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/2/18_2_00005_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/2/18_1_00005_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/2/18_2_00003_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/2/16_1_00003_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/2/18_3_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset1/2/18_3_000050003_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/1/19_2_00004_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/1/19_1_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/1/19_1_00003_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/0/n28_4_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/0/n23_2_00009_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/0/n21_1_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/0/n22_1_00003_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/0/n22_2_00005_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/0/n22_2_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/0/n23_2_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/0/n20_2_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/0/n16_1_00004_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/2/26_1_00003_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/2/15_2_00004_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/2/11_1_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/2/15_1_00006_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/2/26_1_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset2/2/26_1_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/1/14_1_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/1/7_1_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/1/7_1_00005_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/0/n6_1_00004_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/0/n13_1_00003_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/0/n14_1_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/0/n14_1_00007_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/0/n1_1_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/0/n13_2_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/0/n6_1_00006_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/0/n15_2_00005_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/0/n13_1_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/2/4_1_00002_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/2/3_1_00003_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/2/6_1_00001_right.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/2/2_1_00005_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/2/6_1_00006_left.tif',
#  '/home/bishal/Research/Allergic-Rhinitis/Dataset/non_rotate/dataset0/2/2_1_00002_right.tif']

# %%
data = []
labels = []
dirList= []

# %%
# Formatting data and labels
for imagePath in imagePaths:
    # Extract the class label from file name and append to labels
    # 파일 이름에서 클래스 레이블을 추출하고 레이블에 추가함
    label = imagePath.split(os.path.sep)[-2]
    #if label=="2":
     #   labels.append("1")
    #else:
     #   labels.append(label)
    labels.append(label)
    # Load the image, swap color channels, and resize it to be a fixed 224x224 pixels while ignoring the aspect ratio
    # 이미지를 로드하고, 컬러 채널을 스왑하고, 가로 세로 비율을 무시하고 고정 224x224 픽셀로 크기를 조정함
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (224,224))
    # Append to data
    # 데이터에 추가
    data.append(image)

# Convert the data and labels to NumPy arrays while scaling the pixel intensities to the range [0,1]
# 픽셀 강도를 [0,1] 범위로 조정하면서 데이터와 레이블을 NumPy 배열로 변환
data = np.array(data) / 255.0
labels = np.array(labels)

# %%
labels.shape
# Out:
# (90,)

# %%
class_weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.unique(labels), y=labels)
sample_weight = class_weight.compute_sample_weight(class_weight='balanced', y=labels)
print(class_weights)
sample_weight
# Out:
# [0.68181818 1.875      1.        ]
# array([1.875     , 1.875     , 1.875     , 0.68181818, 0.68181818,
#        0.68181818, 0.68181818, 0.68181818, 0.68181818, 0.68181818,
#        0.68181818, 0.68181818, 1.        , 1.        , 1.        ,
#        1.        , 1.        , 1.        , 1.875     , 1.875     ,
#        1.875     , 0.68181818, 0.68181818, 0.68181818, 0.68181818,
#        0.68181818, 0.68181818, 0.68181818, 0.68181818, 1.        ,
#        1.        , 1.        , 1.        , 1.        , 1.        ,
#        1.875     , 1.875     , 1.875     , 1.875     , 0.68181818,
#        0.68181818, 0.68181818, 0.68181818, 0.68181818, 0.68181818,
#        0.68181818, 0.68181818, 0.68181818, 1.        , 1.        ,
#        1.        , 1.        , 1.        , 1.        , 1.875     ,
#        1.875     , 1.875     , 0.68181818, 0.68181818, 0.68181818,
#        0.68181818, 0.68181818, 0.68181818, 0.68181818, 0.68181818,
#        0.68181818, 1.        , 1.        , 1.        , 1.        ,
#        1.        , 1.        , 1.875     , 1.875     , 1.875     ,
#        0.68181818, 0.68181818, 0.68181818, 0.68181818, 0.68181818,
#        0.68181818, 0.68181818, 0.68181818, 0.68181818, 1.        ,
#        1.        , 1.        , 1.        , 1.        , 1.        ])

# %%
[np.unique(labels)]
# Out:
# [array(['0', '1', '2'], dtype='<U1')]

# %%
compute_sample_weight
